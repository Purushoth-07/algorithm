# %% [markdown]
# <a href="https://colab.research.google.com/github/Purushoth-07/algorithm/blob/main/linear_search.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
def linear_search(arr,x):
  for i in range(len(arr)):
    if arr[i] == x:
      return i
  return -1
arr=[2,3,4,10,40]
x=int(input("enter the element to be searched: "))
result=linear_search(arr,x)
if result == -1:
    print("element not found")
else:
    print("element found at index",result)
n=[10,20,50,100,200,500,1000]
time=[0.0001,0.0003,0.0008,0.0015,0.0030,0.0075,0.0150]
plt.plot(n,time)
plt.xlabel("n")
plt.ylabel("time")
plt.title("time Complexity linear search")
plt.show()
# Out:
# enter the element to be searched10
# element found at index 3
